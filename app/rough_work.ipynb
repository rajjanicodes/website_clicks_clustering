# %%
import json
from glob import glob
import os

temp_list = []
DIR_PATH = "/home/rajjani/Downloads/drift/drift/tests/"
all_test_cases = list(glob(os.path.join(DIR_PATH, "cases", "*.json")))

for test_case in all_test_cases:
    with open(test_case, 'r')as fh:
        sequence = json.load(fh)['sequence']
        for seq in sequence:
            temp_list.append(int(seq['page_id']))

print(set(temp_list))
# Out:
# {200, 404}

# %% [markdown]
# There are 5 pages in the website.

# %%
import json
from glob import glob
import os

temp_list = []
DIR_PATH = "/home/rajjani/Downloads/drift/drift/tests/"
all_test_cases = list(glob(os.path.join(DIR_PATH, "cases", "*.json")))

for test_case in all_test_cases:
    with open(test_case, 'r')as fh:
        sequence = json.load(fh)['sequence']
        for seq in sequence:
            if seq['response_code'] == 404:
                print(test_case)
                print(seq)
# Out:
# /home/rajjani/Downloads/drift/drift/tests/cases/case2.json

# %%
import numpy as np


a = np.array([0., 0., 0., 0., 0., 0.])
b = np.array([0.5, 0.5, 0.5, 0.5, 0.5, 0.5])

# %%
a.size
# Out:
# 6

# %%
b.size
# Out:
# 6

# %%
c = np.column_stack((a,b))

# %%
c
# Out:
# array([[0. , 0.5],
#        [0. , 0.5],
#        [0. , 0.5],
#        [0. , 0.5],
#        [0. , 0.5],
#        [0. , 0.5]])

# %%
d = np.array([[1.0, 1.0]])
d.shape
# Out:
# (1, 2)

# %%
c = np.concatenate((c,d), axis=0)

# %%
c
# Out:
# array([[0. , 0.5],
#        [0. , 0.5],
#        [0. , 0.5],
#        [0. , 0.5],
#        [0. , 0.5],
#        [0. , 0.5],
#        [1. , 1. ]])

# %%
c.shape
# Out:
# (7, 2)

# %%
import numpy as np
from sklearn.cluster import DBSCAN
import matplotlib.pyplot as plt


num_points = 200
points = np.random.rand(num_points, 2)

dbscan = DBSCAN(eps=0.09, min_samples=7)
labels = dbscan.fit_predict(points)

unique_labels = np.unique(labels)
colors = plt.cm.Spectral(np.linspace(0, 1, len(unique_labels)))

for label, color in zip(unique_labels, colors):
    if label == -1:
        color = 'black'  # Noise points in black
    class_member_mask = (labels == label)
    xy = points[class_member_mask]
    plt.scatter(xy[:, 0], xy[:, 1], c=color, label=f'Cluster {label}')

plt.legend()
plt.xlabel('X Coordinate')
plt.ylabel('Y Coordinate')
plt.title('DBSCAN Clustering')
plt.show()
# Out:
# /tmp/ipykernel_115811/4245132094.py:20: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   plt.scatter(xy[:, 0], xy[:, 1], c=color, label=f'Cluster {label}')

# %%
x = "3"
y = f'my name is "{x}"'
print([y])
# Out:
# ['my name is "3"']

# %%
len('ctfykwvunjbs/1')
# Out:
# 14

# %%
response_data = {
        "cluster_idx": 1,
        "is_new": True}


output = {
    "cluster_idx": 1,
    "is_new": True
}


print( response_data == output)
# Out:
# True

# %%
max([])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 max([])
#
# ValueError: max() arg is an empty sequence
